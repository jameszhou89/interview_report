# %%
import requests
import json

# %%
# 把公司的接口封装为函数
def ths_gpt(temperature,max_tokens,prompt_text):
    url = "http://avatar.aicubes.cn/vtuber/auth/api/oauth/v1/login"

    payload = {
        "app_id": "////////",
        "app_secret": "///////// "
    }
    headers = {"content-type": "application/json"}

    response1 = requests.request("POST", url, json=payload, headers=headers)
    data1 = json.loads(response1.text)
    user_id = data1['data']['user_id']
    token = data1['data']['token']

    url = "http://avatar.aicubes.cn/vtuber/ai_access/chatgpt/v1/chat/completions"

    payload = {
        "messages": [
        {
            "role": "user",
            "content": prompt_text
        }
        ],
        "temperature": temperature,
        "max_tokens": max_tokens
    }

    headers = {
        "userId": user_id,
        "token": token,
        "content-type": "application/json"
    }

    response2 = requests.request("POST", url, json=payload, headers=headers)
    data2 = json.loads(response2.text)
    #print(data2)
    output = data2['data']['choices'][0]['message']['content']
    # print(output)
    return output

# %%
### 单题能力练习面试报告

# %%
# 思路：
#  分开两个prompt，一个处理完整性+综合建议，一个处理逻辑性+创新性

# why?
#   1.分开两个prompt，打分质量更高；
#   2.能够接受更长的文本 answer = longanswer + shortanswer*6 2000个左右的字也都可以；

# %%
question ="""
请解释“归纳推理”和“演绎推理”之间的区别，并举出一个例子。
"""

# %%
reference = """
解题思路：
1. 介绍归纳推理和演绎推理的定义和区别：
   1.1 归纳推理是从特殊到一般的推理方式，通过已知的一些具体事实或现象，归纳出普遍规律或结论；
   1.2 演绎推理是从一般到特殊的推理方式，根据已知的一般规律或原理，推导出具体的结论或结果。
2. 举例说明归纳推理和演绎推理的应用场景：
   2.1 归纳推理：通过观察某个人的行为习惯，推断出他的性格特点；
   2.2 演绎推理：根据数学公式推导出某个具体数值。
3. 总结归纳推理和演绎推理的优缺点：
   3.1 归纳推理的优点是适用范围广，但缺点是推断出的结论可能不够准确；
   3.2 演绎推理的优点是推断出的结论比较准确，但缺点是适用范围较窄。
4. 提醒面试者在面试中如何应用归纳推理和演绎推理：
   4.1 面试者需要根据实际情况选择合适的推理方式；
   4.2 面试者需要在面试中充分展现自己的推理能力，包括归纳和演绎推理。

"""

# %%
longanswer = """
演绎推理和归纳推理是有非常大的区别的，首先的话，演绎推理是一个由大到小的过程，也就是说首先我知道一个大的前提，\
然后再推出一个小的东西，就比如的话是所有人都会死，那么我也会死，那这就是一个小推大的过程，所有人都会死，我也是人，\
所以我也会死。然后这是前提和结论是有必然关系的，所以这是演绎推理一个大推小，而归纳推理的话就是前提和结论就是没有什么必然的关系了。\
公家推理的话是小推大，就比如说是我会死，那所有人都会死，就是我以我个人，我说我会死，然后我用一个人推所有人，\
这就并没有什么一个普遍的规律，因为我只是一个个体，我，我不能用我自己个体的特殊性去推整体的一个东西，\
死可能是一个必然的结果。但如果说是我说我爱钢琴，那么我不可能说不可能是所有人爱钢琴，对吧？\
那演绎推理的话就不一样，演绎推理的话就是所有人爱钢琴，所以我爱钢琴，那我觉得就是他俩的一个区别。\
演绎推理是一个归纳性、总结性的，是由普遍到一般也那个归纳推理的话就是从个别个体到普遍，这大概是我对归纳推理和演绎推理的一个区别的判断\
"""

# %%
shortanswer = """
"呃我认为的话，首先的话，归纳推理的话，啊。应该是基于事实。基于一些数据，然后，演绎处理的话是应该更多的是基于逻辑的分析，可能他并没有很多的数据支撑。
嗯，就举一个例子的话，就比如说是呃。杂交实验吧，就是我们生物学的这个东西。呃。归纳推理的话就是他观察到就是植物的生长状态，然后从而去得到然后，但是点一推理的话，就因为它是杂角吗？杂交的话，是一个品种，它能观察两个品种达交，
但是，不能观察它三个品种，四个品种就是很多品种之后，他就无法去观察了。他先是用两先是得到一个，再得到两个，再得到三个发现他们的规律相同的，然，然后就进而去，可以推理到四个五个123使用到的归纳归纳推理456。那就用的是演绎推理。"
"""

# %%
### prompt1:观点完整性、综合建议

# %%
grade_prompt1 = f"""
你是一个面试专家，曾经在google/facebook/阿里巴巴/腾讯等科技巨头工作,非常善于倾听候选人的回答，并进行分析诊断.
你现在的任务是针对[问题]的问题，对比[解题思路]和[候选人观点]的要点，对候选人回答进行评价。

[问题]:
```
{question}
```

[解题思路]:
```
{reference}
```

[候选人观点]:
```
{longanswer}
```

请你务必采用以下格式进行思考和输出:

对比[候选人观点]和[解题思路]：

```
你的对比过程（对比思考候选人观点的优劣，控制在100个字）
```

对候选人观点的完整性进行点评：
```
你的点评内容（点评其内容是否涵盖了解题思路的各个方面，是否有所遗漏，字数控制在50个字）
```

对候选人观点的完整性进行打分:
```
你的打分（只要输出1~10之间的分数即可，1分代表最低，10分代表最高）
```

对候选人观点的综合提升建议:
```
你的建议（从观点完整性、逻辑性和创新性三个维度进行建议，字数控制在150个字）
```

Let's think step by step

"""

# %%
print(grade_prompt1)
# Out:
# 你是一个面试专家，曾经在google/facebook/阿里巴巴/腾讯等科技巨头工作,非常善于倾听候选人的回答，并进行分析诊断.
# 你现在的任务是针对[问题]的问题，对比[解题思路]和[候选人观点]的要点，对候选人回答进行评价。
#
# [问题]:
# ```
#
# 请解释“归纳推理”和“演绎推理”之间的区别，并举出一个例子。
#
# ```
#
# [解题思路]:
# ```
#
# 解题思路：
# 1. 介绍归纳推理和演绎推理的定义和区别：
#    1.1 归纳推理是从特殊到一般的推理方式，通过已知的一些具体事实或现象，归纳出普遍规律或结论；
#    1.2 演绎推理是从一般到特殊的推理方式，根据已知的一般规律或原理，推导出具体的结论或结果。
# 2. 举例说明归纳推理和演绎推理的应用场景：
#    2.1 归纳推理：通过观察某个人的行为习惯，推断出他的性格特点；
#    2.2 演绎推理：根据数学公式推导出某个具体数值。
# 3. 总结归纳推理和演绎推理的优缺点：
#    3.1 归纳推理的优点是适用范围广，但缺点是推断出的结论可能不够准确；
#    3.2 演绎推理的优点是推断出的结论比较准确，但缺点是适用范围较窄。
# 4. 提醒面试者在面试中如何应用归纳推理和演绎推理：
#    4.1 面试者需要根据实际情况选择合适的推理方式；
#    4.2 面试者需要在面试中充分展现自己的推理能力，包括归纳和演绎推理。
#
#
# ```
#
# [候选人观点]:
# ```
#
# ...

# %%
grade_result1 = ths_gpt(0.2,1000,grade_prompt1)
print(grade_result1)
# Out:
# 对比候选人观点和解题思路：
# 候选人观点中提到了演绎推理和归纳推理的区别，但是表述不够清晰，没有提到归纳推理是从特殊到一般，演绎推理是从一般到特殊的概念。同时，候选人观点中的例子也不够恰当，没有很好地说明两种推理方式的应用场景。解题思路中的定义和例子都更加清晰明了，同时还总结了两种推理方式的优缺点，并提供了面试建议。
#
# 对候选人观点的完整性进行点评：
# 候选人观点虽然提到了演绎推理和归纳推理的区别，但是表述不够清晰，没有涵盖解题思路中的所有方面，同时例子也不够恰当，有所遗漏。
#
# 对候选人观点的完整性进行打分：
# 6分
#
# 对候选人观点的综合提升建议：
# 建议候选人在回答问题时，先理清思路，确保表述清晰明了，同时可以多准备一些恰当的例子来说明问题。在面试中，可以多加练习，提高自己的表达能力和推理能力。

# %%
### prompt2:观点逻辑性和创新性打分

# %%
grade_prompt2 = f"""
你是一个面试专家，曾经在google/facebook/阿里巴巴/腾讯等科技巨头工作,非常善于倾听候选人的回答，并进行分析诊断.
你现在的任务是针对[问题]的问题，对比[解题思路]和[候选人观点]的要点，对候选人回答进行评价。

[问题]:
```
{question}
```
[解题思路]:
```
{reference}
```
[候选人观点]:
```
{longanswer}
```

请你务必采用以下格式进行思考和输出:

对比[候选人观点]和[解题思路]：

```
你的对比过程（对比思考候选人观点的优劣，控制在100个字）
```

对候选人观点的逻辑性进行点评：
```
你的点评内容（点评其内容是否有逻辑性，是否有条理，控制在100个字）
```

对候选人观点的逻辑性进行打分:
```
你的打分（务必只要输出1~10之间的分数即可，1分代表最低，10分代表最高）
```

对候选人观点的创新性进行点评：
```
你的点评内容（点评其内容是否有新颖的思路和独特的见解，控制在100个字）
```

对候选人观点的创新性进行打分:
```
你的打分（务必只要输出1~10之间的分数，1分代表最低，10分代表最高）
```

Let's think step by step

"""

# %%
print(grade_prompt2)
# Out:
# 你是一个面试专家，曾经在google/facebook/阿里巴巴/腾讯等科技巨头工作,非常善于倾听候选人的回答，并进行分析诊断.
# 你现在的任务是针对[问题]的问题，对比[解题思路]和[候选人观点]的要点，对候选人回答进行评价。
#
# [问题]:
# ```
#
# 请解释“归纳推理”和“演绎推理”之间的区别，并举出一个例子。
#
# ```
# [解题思路]:
# ```
#
# 解题思路：
# 1. 介绍归纳推理和演绎推理的定义和区别：
#    1.1 归纳推理是从特殊到一般的推理方式，通过已知的一些具体事实或现象，归纳出普遍规律或结论；
#    1.2 演绎推理是从一般到特殊的推理方式，根据已知的一般规律或原理，推导出具体的结论或结果。
# 2. 举例说明归纳推理和演绎推理的应用场景：
#    2.1 归纳推理：通过观察某个人的行为习惯，推断出他的性格特点；
#    2.2 演绎推理：根据数学公式推导出某个具体数值。
# 3. 总结归纳推理和演绎推理的优缺点：
#    3.1 归纳推理的优点是适用范围广，但缺点是推断出的结论可能不够准确；
#    3.2 演绎推理的优点是推断出的结论比较准确，但缺点是适用范围较窄。
# 4. 提醒面试者在面试中如何应用归纳推理和演绎推理：
#    4.1 面试者需要根据实际情况选择合适的推理方式；
#    4.2 面试者需要在面试中充分展现自己的推理能力，包括归纳和演绎推理。
#
#
# ```
# [候选人观点]:
# ```
#
# ...

# %%
grade_result2 = ths_gpt(0.2,1000,grade_prompt2)
print(grade_result2)
# Out:
# 对比候选人观点和解题思路：
# 候选人观点中对归纳推理和演绎推理的定义和区别有一定的准确性，但表述不够清晰，缺乏条理性。同时，候选人观点中对归纳推理和演绎推理的应用场景和优缺点的说明也不够充分。相比之下，解题思路中对归纳推理和演绎推理的定义和区别、应用场景和优缺点的说明更加清晰明了，条理性更强。
# 对候选人观点的逻辑性进行点评：
# 候选人观点中虽然对归纳推理和演绎推理的定义和区别有一定的准确性，但表述不够清晰，缺乏条理性，同时对应用场景和优缺点的说明也不够充分，逻辑性不够强。
# 对候选人观点的逻辑性进行打分：
# 6分
# 对候选人观点的创新性进行点评：
# 候选人观点中对归纳推理和演绎推理的定义和区别的判断比较传统，没有新颖的思路和独特的见解。
# 对候选人观点的创新性进行打分：
# 3分

# %%
### 多题综合面试报告

# %%
# 思路
# 每道题按照单题面试报告的prompt(prompt1/prompt2)进行计算
# 总体建议将所有单题的建议汇总进行总结

# %%
## prompt3:多题综合面试-提升建议

# %%
s1 = """
建议候选人在回答问题时，要注意表述清晰，有条理，同时要注意全面性和创新性，可以从不同的角度出发，\
提出新颖的思路和独特的见解，以提升回答的质量。\

"""

# %%
s2 = """
建议候选人在回答问题时，要注意表述清晰，准确，尽量避免用词不当的情况。\
同时，可以在回答中加入自己的思考和见解，提高回答的创新性和逻辑性。\
最后，可以在回答结束时，对问题进行总结，并给出应用建议，以提高回答的完整性和实用性。\

"""

# %%
s3 = """
建议候选人在回答问题时，先理清思路，表述清晰，避免重复和语言表述不够流畅的问题。\
在举例时，要注意例子的恰当性和准确性，尽量涵盖解题思路的各个方面。\
同时，可以多进行练习和积累，提高对归纳推理和演绎推理的理解和应用能力。\

"""

# %%
s4 = """
建议候选人在回答问题时，先简要介绍定义和区别，再结合恰当的例子进行说明。\
同时，需要注意表述清晰，避免出现口误或语法错误。在面试前可以多练习，提高回答的流畅度和准确性。\
"""

# %%
suggestion = s1 + s2+s3+s4

# %%
print(suggestion)
# Out:
# 建议候选人在回答问题时，要注意表述清晰，有条理，同时要注意全面性和创新性，可以从不同的角度出发，提出新颖的思路和独特的见解，以提升回答的质量。
#
# 建议候选人在回答问题时，要注意表述清晰，准确，尽量避免用词不当的情况。同时，可以在回答中加入自己的思考和见解，提高回答的创新性和逻辑性。最后，可以在回答结束时，对问题进行总结，并给出应用建议，以提高回答的完整性和实用性。
#
# 建议候选人在回答问题时，先理清思路，表述清晰，避免重复和语言表述不够流畅的问题。在举例时，要注意例子的恰当性和准确性，尽量涵盖解题思路的各个方面。同时，可以多进行练习和积累，提高对归纳推理和演绎推理的理解和应用能力。
#
# 建议候选人在回答问题时，先简要介绍定义和区别，再结合恰当的例子进行说明。同时，需要注意表述清晰，避免出现口误或语法错误。在面试前可以多练习，提高回答的流畅度和准确性。

# %%
summarize_require1 = """
1.字数要求：将总字数控制在200个字左右；
2.内容要求：请不要新增其他的建议，或者遗漏原有的建议。

"""

# %%
summarize_prompt1 = f"""
你是一个面试专家，曾经在google/facebook/阿里巴巴/腾讯等科技巨头工作,非常善于倾听候选人的回答，并进行分析诊断.
你的任务是遵循[要求]里面的要求，将[对候选人的面试建议]里面的所有建议，从观点完整性、逻辑性和创新性三个维度提炼总结。


[要求]：
```
{summarize_require1}
```

[对候选人的面试建议]：
```
{suggestion}
```

请务必按照以下格式进行思考和输出：

对候选人观点的完整性建议:
```
你的建议
```

对候选人观点的逻辑性建议:
```
你的建议
```

对候选人观点的创新性建议:
```
你的建议
```

Let's think step by step

"""

# %%
print(summarize_prompt1)
# Out:
# 你是一个面试专家，曾经在google/facebook/阿里巴巴/腾讯等科技巨头工作,非常善于倾听候选人的回答，并进行分析诊断.
# 你的任务是遵循[要求]里面的要求，将[对候选人的面试建议]里面的所有建议，从观点完整性、逻辑性和创新性三个维度提炼总结。
#
#
# [要求]：
# ```
#
# 1.字数要求：将总字数控制在200个字左右；
# 2.内容要求：请不要新增其他的建议，或者遗漏原有的建议。
#
#
# ```
#
# [对候选人的面试建议]：
# ```
#
# 建议候选人在回答问题时，要注意表述清晰，有条理，同时要注意全面性和创新性，可以从不同的角度出发，提出新颖的思路和独特的见解，以提升回答的质量。
#
# 建议候选人在回答问题时，要注意表述清晰，准确，尽量避免用词不当的情况。同时，可以在回答中加入自己的思考和见解，提高回答的创新性和逻辑性。最后，可以在回答结束时，对问题进行总结，并给出应用建议，以提高回答的完整性和实用性。
#
# 建议候选人在回答问题时，先理清思路，表述清晰，避免重复和语言表述不够流畅的问题。在举例时，要注意例子的恰当性和准确性，尽量涵盖解题思路的各个方面。同时，可以多进行练习和积累，提高对归纳推理和演绎推理的理解和应用能力。
#
# 建议候选人在回答问题时，先简要介绍定义和区别，再结合恰当的例子进行说明。同时，需要注意表述清晰，避免出现口误或语法错误。在面试前可以多练习，提高回答的流畅度和准确性。
# ```
#
# 请务必按照以下格式进行思考和输出：
#
# 对候选人观点的完整性建议:
# ```
# 你的建议
# ```
#
# 对候选人观点的逻辑性建议:
# ```
# 你的建议
# ```
#
# 对候选人观点的创新性建议:
# ```
# 你的建议
# ```
#
# Let's think step by step

# %%
summarize_result1 = ths_gpt(0.2,1000,summarize_prompt1)
print(summarize_result1)
# Out:
# 对候选人观点的完整性建议:
# 建议候选人在回答问题时，要注意全面性和实用性，可以从不同的角度出发，提出新颖的思路和独特的见解，以提升回答的质量。在回答结束时，可以对问题进行总结，并给出应用建议，以提高回答的完整性和实用性。
#
# 对候选人观点的逻辑性建议:
# 建议候选人在回答问题时，要注意表述清晰，有条理，尽量避免用词不当的情况。可以在回答中加入自己的思考和见解，提高回答的创新性和逻辑性。在举例时，要注意例子的恰当性和准确性，尽量涵盖解题思路的各个方面。
#
# 对候选人观点的创新性建议:
# 建议候选人在回答问题时，可以从不同的角度出发，提出新颖的思路和独特的见解，以提升回答的质量。在回答中加入自己的思考和见解，提高回答的创新性和逻辑性。可以多进行练习和积累，提高对归纳推理和演绎推理的理解和应用能力。
